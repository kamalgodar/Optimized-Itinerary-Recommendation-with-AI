# %% [markdown]
# # Ant Colony Optimization based Itinerary Recommender
#
# ## "The title is pretty much self-explanatory. We will be following the ACO framework shown below:"

# %% [markdown]
# ###### ACO Framework
#
# % Create Graph
#
# % Draw Graph
#
# %% ACO algorithm
#
#     % Define Initial Parameters
#
#     % Main loop
#
#     for i = 1 to max_iter:
#         % Create ants
#         % Calculate fitness value of all ants
#         % Find the best ant
#         % Update the pheromone matrix
#         % Implement Evaporation
#         % Display results
#     end

# %%
# Import the libraries 

import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Import the dataset
top_dests=pd.read_csv("../../Datasets/final_destinations_of_ktm_latest.csv")

# %%
print(top_dests.head())
# Out:
#    Unnamed: 0  dest_id                 title  \
# 0           0        1      Boudhanath Stupa
# 1           1        2  Swayambhunath Temple
# 2           2        3  Pashupatinath Temple
# 3           3        4     Chandragiri Hills
# 4           4        5       Kopan Monastery
#
#                                     genre   latitude  longitude  \
# 0  history:art_and_architecture:religious  27.721506  85.359809
# 1  history:art_and_architecture:religious  27.714930  85.288146
# 2  history:art_and_architecture:religious  27.710446  85.346503
# 3                                  nature  27.671050  85.262664
# 4  history:art_and_architecture:religious  27.742544  85.362208
#
#                                              img_url
# 0  ......
# 1  ......
# 2  ......
# 3  ......
# 4  ......

# %%
# drop the first column (index)
print(top_dests.columns)
top_dests=top_dests.drop(['Unnamed: 0'],axis=1)
print(top_dests)
# Out:
# Index(['Unnamed: 0', 'dest_id', 'title', 'genre', 'latitude', 'longitude',
#        'img_url'],
#       dtype='object')
#       dest_id                                title  \
# 0           1                     Boudhanath Stupa
# 1           2                 Swayambhunath Temple
# 2           3                 Pashupatinath Temple
# 3           4                    Chandragiri Hills
# 4           5                      Kopan Monastery
# ...       ...                                  ...
# 2328     2341         Zeal Nepal Trek & Expedition
# 2329     2342                        Mohit Sunuwar
# 2330     2343  SITA (Travel Corporation India Ltd)
# 2331     2344                       Himalayan Hike
# 2332     2345                            River Fun
#
#                                            genre   latitude  longitude  \
# 0         history:art_and_architecture:religious  27.721506  85.359809
# 1         history:art_and_architecture:religious  27.714930  85.288146
# 2         history:art_and_architecture:religious  27.710446  85.346503
# 3                                         nature  27.671050  85.262664
# 4         history:art_and_architecture:religious  27.742544  85.362208
# ...                                          ...        ...        ...
# 2328                                     history        NaN        NaN
# 2329                                   adventure        NaN        NaN
# 2330                                     history        NaN        NaN
# 2331  history:art_and_architecture:entertainment        NaN        NaN
# 2332              nature:adventure:entertainment        NaN        NaN
#
#                                                 img_url
# 0     ......
# 1     ......
# 2     ......
# 3     ......
# 4     ......
# ...                                                 ...
# 2328                                                NaN
# 2329                                                NaN
# 2330                                                NaN
# 2331                                                NaN
# 2332                                                NaN
#
# [2333 rows x 6 columns]

# %%
top_dests.to_csv("../../Datasets/final_destinations_of_ktm_latest.csv")

# %%
# select the first 189 destinations as they're the destinations having the latitude and longitude currently
top_dests=top_dests[:189]

# %%
print(top_dests.tail())
# Out:
#      dest_id                                title  \
# 184      197  Nepal Alibaba Treks & Tours Pvt Ltd
# 185      198                  Alpine Ramble Treks
# 186      199      Info Nepal Treks and Expedition
# 187      200          Epic Adventures - Day Tours
# 188      201               Hiking Adventure Treks
#
#                                           genre   latitude  longitude img_url
# 184                                     history  27.737544  85.302841     NaN
# 185                                     history  27.719162  85.306492     NaN
# 186  history:art_and_architecture:entertainment  27.716040  85.308885     NaN
# 187              art_and_architecture:religious  27.700972  85.280179     NaN
# 188  history:art_and_architecture:entertainment  27.717671  85.309687     NaN

# %%
# since we'll be dealing only with latitude and longitude at the moment
# only filter those columns along with the title
print(top_dests[['title','latitude','longitude']])
# Out:
#                                    title   latitude  longitude
# 0                       Boudhanath Stupa  27.721506  85.359809
# 1                   Swayambhunath Temple  27.714930  85.288146
# 2                   Pashupatinath Temple  27.710446  85.346503
# 3                      Chandragiri Hills  27.671050  85.262664
# 4                        Kopan Monastery  27.742544  85.362208
# ..                                   ...        ...        ...
# 184  Nepal Alibaba Treks & Tours Pvt Ltd  27.737544  85.302841
# 185                  Alpine Ramble Treks  27.719162  85.306492
# 186      Info Nepal Treks and Expedition  27.716040  85.308885
# 187          Epic Adventures - Day Tours  27.700972  85.280179
# 188               Hiking Adventure Treks  27.717671  85.309687
#
# [189 rows x 3 columns]

# %%
# # let's plot the graph again 
# %matplotlib inline 
# plt.figure(figsize=(12,12)) 

# for lat,long in zip(top_dests['latitude'],top_dests['longitude']):
    
#     for another_lat,another_long in zip(top_dests['latitude'],top_dests['longitude']):
        
#         # create a list holding the two latitude
#         lat_list=[lat,another_lat]
#         # also create a list holding the two longitudes 
#         long_list=[long,another_long]
#         plt.plot(lat_list,long_list,color='blue', marker='o', linestyle='solid',linewidth=2, markersize=8,mfc = 'white')
# #     plt.plot(lat_list,top_n_dests['longitude'],color='blue', marker='o', linestyle='solid',linewidth=2, markersize=8,mfc = 'white')

# for title,x,y in zip(top_dests['title'],top_dests['latitude'],top_dests['longitude']):

#     label = "{}".format(title)

#     plt.annotate(label, # this is the text
#                  (x,y), # these are the coordinates to position the label
#                  textcoords="offset points", # how to position the text
#                  xytext=(0,10), # distance from text to points (x,y)
#                  ha='center') # horizontal alignment can be left, right or center
# plt.show()

# %%
# let's just pick n=189 
n=189 #graph size
top_n_dests=top_dests[:n]
print(top_n_dests)

# define a starting point 
starting_point=0
# Out:
#      dest_id                                title  \
# 0          1                     Boudhanath Stupa
# 1          2                 Swayambhunath Temple
# 2          3                 Pashupatinath Temple
# 3          4                    Chandragiri Hills
# 4          5                      Kopan Monastery
# ..       ...                                  ...
# 184      197  Nepal Alibaba Treks & Tours Pvt Ltd
# 185      198                  Alpine Ramble Treks
# 186      199      Info Nepal Treks and Expedition
# 187      200          Epic Adventures - Day Tours
# 188      201               Hiking Adventure Treks
#
#                                           genre   latitude  longitude  \
# 0        history:art_and_architecture:religious  27.721506  85.359809
# 1        history:art_and_architecture:religious  27.714930  85.288146
# 2        history:art_and_architecture:religious  27.710446  85.346503
# 3                                        nature  27.671050  85.262664
# 4        history:art_and_architecture:religious  27.742544  85.362208
# ..                                          ...        ...        ...
# 184                                     history  27.737544  85.302841
# 185                                     history  27.719162  85.306492
# 186  history:art_and_architecture:entertainment  27.716040  85.308885
# 187              art_and_architecture:religious  27.700972  85.280179
# 188  history:art_and_architecture:entertainment  27.717671  85.309687
#
#                                                img_url
# 0    ......
# 1    ......
# 2    ......
# 3    ......
# 4    ......
# ..                                                 ...
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
#
# [189 rows x 6 columns]

# %%
# remove the duplicate entry

print(len(top_n_dests['latitude'].unique()))
print(len(top_n_dests['longitude'].unique()))

#print out the duplicated latitude,longitude
duplicate_lat_long = top_n_dests[top_n_dests.duplicated(['latitude','longitude'])]
print(duplicate_lat_long)

#remove the duplicate entries, keeping only the first
top_n_dests=top_n_dests.drop_duplicates(subset=['latitude', 'longitude'], keep='first')
print(len(top_n_dests))
# print(top_n_dests[top_n_dests['latitude']=='27.7154575'])
# Out:
# 185
# 185
#      dest_id              title                                   genre  \
# 119      125  Woodcraft Gallery  history:art_and_architecture:religious
# 121      127    Aviation Museum            history:art_and_architecture
# 137      147      Shobabaghwati     history:art_and_architecture:nature
#
#       latitude  longitude img_url
# 119  27.715457  85.306667     NaN
# 121  27.693795  85.351280     NaN
# 137  27.714930  85.288146     NaN
# 186

# %%
#save to a dataset 
top_n_dests.to_csv("../../Datasets/final_dest_ktm_with_duplicates_removed.csv")

# %%
n=186 # had to change n too to 186 after removing the duplicates

# %%
def plot_graph(ax,fig):
    """
        Function to plot the graph of matrix for every edge between the given nodes
    """

    for lat,long in zip(top_n_dests['latitude'],top_n_dests['longitude']):
        for another_lat,another_long in zip(top_n_dests['latitude'],top_n_dests['longitude']):

            # create a list holding the two latitude
            lat_list=[lat,another_lat]
            # also create a list holding the two longitudes 
            long_list=[long,another_long]

            ax.plot(lat_list,long_list,color='blue', marker='o', linestyle='solid',linewidth=2, markersize=8,mfc = 'white')
            #     plt.plot(lat_list,top_n_dests['longitude'],color='blue', marker='o', linestyle='solid',linewidth=2, markersize=8,mfc = 'white')
            fig.canvas.draw()
            
    #adding label to each node
    for title,x,y in zip(top_n_dests['title'],top_n_dests['latitude'],top_n_dests['longitude']):

        label = "{}".format(title)

        ax.annotate(label, # this is the text
                     (x,y), # these are the coordinates to position the label
                     textcoords="offset points", # how to position the text
                     xytext=(-5,5), # distance from text to points (x,y)
                     ha='center') # horizontal alignment can be left, right or center

# %%
# also meanwhile let's create a matrix called 'graph' to store the weights for each edges
graph=np.zeros((n,n))

# 
def create_graph():

    # iterators to iterate through the graph
    i=0
    j=0

    for lat,long in zip(top_n_dests['latitude'].astype(float),top_n_dests['longitude'].astype(float)):
        j=0
        for another_lat,another_long in zip(top_n_dests['latitude'].astype(float),top_n_dests['longitude'].astype(float)):
            #edge weight(Euclidean distance)
            distance_between_the_places=np.sqrt((lat-another_lat)**2+(long-another_long)**2)
            #print(distance_between_the_places)

            #and store it in the 'graph' matrix
            graph[i][j]=distance_between_the_places
            #increment j 
            j+=1

        #increment i
        i+=1

# %%
create_graph()
print(graph)
# Out:
# [[0.         0.07196422 0.01730239 ... 0.05121585 0.08223434 0.05026862]
#  [0.07196422 0.         0.05852919 ... 0.02076949 0.01607098 0.02171472]
#  [0.01730239 0.05852919 0.         ... 0.03803103 0.06699673 0.03751842]
#  ...
#  [0.05121585 0.02076949 0.03803103 ... 0.         0.0324203  0.00181725]
#  [0.08223434 0.01607098 0.06699673 ... 0.0324203  0.         0.03390473]
#  [0.05026862 0.02171472 0.03751842 ... 0.00181725 0.03390473 0.        ]]

# %%
# Define the initial parameters of ACO
max_iter=100 #max no of iterations
ant_no=10 #number of ants 

#initial pheromone concentration
tau_0=10*1/(n*np.mean(graph))

#initial pheromone matrix
tau = tau_0*np.ones((n,n))
print("Initial pheromone matrix (Tau):")
print(tau)

#desirability/quality of each edge,eta
eta=1/graph #inverse of cost (distance)
print("Desirability matrix (Eta):")
print(eta)

rho=0.05 #evaporation rate
alpha=2 #pheromone exponential parameter
beta=1 #edge desirabiltu/quality exponential parameter
# Out:
# Initial pheromone matrix (Tau):
# [[0.6450435 0.6450435 0.6450435 ... 0.6450435 0.6450435 0.6450435]
#  [0.6450435 0.6450435 0.6450435 ... 0.6450435 0.6450435 0.6450435]
#  [0.6450435 0.6450435 0.6450435 ... 0.6450435 0.6450435 0.6450435]
#  ...
#  [0.6450435 0.6450435 0.6450435 ... 0.6450435 0.6450435 0.6450435]
#  [0.6450435 0.6450435 0.6450435 ... 0.6450435 0.6450435 0.6450435]
#  [0.6450435 0.6450435 0.6450435 ... 0.6450435 0.6450435 0.6450435]]
# Desirability matrix (Eta):
# [[         inf  13.89579436  57.79547534 ...  19.52520696  12.16037014
#    19.89312809]
#  [ 13.89579436          inf  17.08549118 ...  48.14755215  62.22394267
#    46.05172062]
#  [ 57.79547534  17.08549118          inf ...  26.29431683  14.92610228
#    26.65357516]
#  ...
#  [ 19.52520696  48.14755215  26.29431683 ...          inf  30.84487323
#   550.28109577]
#  [ 12.16037014  62.22394267  14.92610228 ...  30.84487323          inf
#    29.49441031]
#  [ 19.89312809  46.05172062  26.65357516 ... 550.28109577  29.49441031
#            inf]]
# /tmp/ipykernel_6490/1501364078.py:14: RuntimeWarning: divide by zero encountered in true_divide
#   eta=1/graph #inverse of cost (distance)

# %%
print(tau[2,:]**alpha)
# Out:
# [0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112
#  0.41608112 0.41608112 0.41608112 0.41608112 0.41608112 0.41608112]

# %%
print(eta[2,:]**beta)
# Out:
# [5.77954753e+01 1.70854912e+01            inf 1.07951909e+01
#  2.79845177e+01 2.57216568e+01 2.90825411e+01 3.69544626e+00
#  2.35267341e+01 2.74553501e+01 9.64190155e+00 7.08735180e+00
#  7.38031557e+00 1.25360477e+01 2.39614361e+01 2.45067304e+02
#  1.23393973e+01 3.25762666e+01 3.25818548e+01 2.35501398e+01
#  6.87737315e+00 1.79003876e+01 2.97881172e+01 8.48965890e+00
#  1.89775738e+01 2.53394803e+01 1.32182935e+01 2.52922237e+01
#  2.62012936e+01 4.89178811e+00 1.68081140e+01 2.38343266e+01
#  8.13897748e+00 2.73031804e+01 1.23452097e+01 4.02541142e+01
#  9.74101212e+00 5.36210835e+01 1.60165042e+01 1.02069494e+01
#  2.43787287e+01 1.76717137e+01 2.58729003e+01 1.25161304e+01
#  2.35370819e+01 9.90181263e+02 2.38932355e+01 8.13077797e+01
#  5.09979350e+01 2.56139267e+01 5.74891383e+01 2.96382353e+01
#  1.64259627e+01 2.07916622e+02 9.13698039e+00 3.22731952e+01
#  1.60389760e+01 2.33943404e+01 2.53347666e+01 2.72437047e+01
#  2.31330127e+01 2.90870144e+01 2.62989038e+01 2.40616635e+01
#  1.92358154e+01 2.62395204e+01 2.06118670e+01 2.49494869e+01
#  2.59459532e+01 3.36571573e+01 2.62141636e+01 2.86178736e+01
#  2.68390826e+01 5.64788673e+01 2.99004662e+01 2.49066116e+01
#  2.30638476e+01 1.42744427e+01 1.69354812e+01 2.39014215e+01
#  3.21673448e+01 2.48215292e+01 5.77282173e+01 3.31687187e+01
#  3.22957627e+01 2.35477532e+01 3.48875314e+01 1.14592382e+01
#  1.57217502e+01 1.45074261e+01 3.13185632e+01 5.94094447e+01
#  2.05232348e+01 2.90809938e+02 2.82288855e+01 6.87538175e-01
#  3.89695911e+01 5.72397386e+00 2.00934225e+01 1.32467566e+01
#  4.27069663e+01 4.07949132e+02 3.29073965e+01 8.83388512e+01
#  2.57709452e+01 9.55649604e+00 2.04995327e+01 3.28621556e+01
#  2.58211331e+01 5.58889796e-01 2.36626789e+01 5.97733875e+01
#  8.76025231e+00 1.62417403e+01 1.43247325e+01 1.39853714e+01
#  2.80458200e+01 2.45319383e+01 1.49614446e+03 2.56382215e+01
#  2.32175865e+01 2.54773434e+01 2.46041305e+01 2.21360504e+01
#  6.70048337e+00 3.10388182e+01 1.77119481e+01 2.64239344e+01
#  2.72709166e+01 1.67539280e+01 2.56723582e+01 2.59277836e+01
#  1.05935089e+01 5.71582310e+01 9.29610309e+00 2.58690544e+01
#  2.31190051e+01 3.93503871e+01 2.55855538e+01 2.39002029e+01
#  2.51159130e+01 2.67187475e+01 2.50670614e+01 2.38170098e+01
#  2.44050438e+01 2.49128739e+01 2.54252608e+01 2.73362982e+01
#  1.79581564e+01 2.49252641e+01 2.68085309e+01 2.66123818e+01
#  2.71526352e+01 1.90541419e+01 2.73459700e+01 2.87335584e+01
#  1.90664548e+01 1.40322179e+01 2.43663503e+01 2.50556619e+01
#  2.32581907e+01 2.65356290e+01 2.24823061e+01 2.65812530e+01
#  2.66456506e+01 2.52688734e+01 2.74827267e+01 2.71734569e+01
#  2.83311839e+01 2.47796835e+01 2.54986870e+01 2.48237590e+01
#  1.06319557e+01 2.45526027e+01 2.73427080e+01 2.74612337e+01
#  2.60080087e+01 2.48805513e+01 2.53503159e+01 2.53694440e+01
#  2.82627455e+01 1.94599976e+01 2.44204941e+01 2.62943168e+01
#  1.49261023e+01 2.66535752e+01]

# %% [markdown]
# ## Now moving on to the main loop of ACO

# %%
# defining a function to create the ant colony 
def create_colony(graph,node_no,ant_no,tau,eta,alpha,beta,initial_node):
    """
        creates an ant colony
    """
    # create a list called 'colony'
    # inside it, there will be ants ( represented by the indices)
    # each position contains other list called 'tour' that contains
    # the tour completed by each ant
    colony=[[] for _ in range(ant_no)] #size of the colony=no of ants
    
    # Run iterations equal to the number of ants 
    for i in range(ant_no):
        
        # define the initial node
        # we should take it as a parameter actually 
        # but let's take it random for now
        # initial_node=np.random.randint(0,node_no)
        
        # nope we changed our mind 
        initial_node=initial_node
        colony[i].append(initial_node)
        
#         print(colony)
        
        for j in range(node_no-1):
            #to choose the rest of the nodes
            
            #current node is the last node in the list
            current_node=int(colony[i][-1])
#             print("current node:",current_node)
            
            #use the following formula to calculate the probability 
            p_all_nodes=(tau[current_node,:]**alpha)*(eta[current_node,:]**beta)
#             print("Prob:",p_all_nodes)
            
            #make the probability of the visited nodes 0
#             print("colony:",colony)
            for node in colony[i]:
                p_all_nodes[node]=0
                
            #calculate the final probability
            p=p_all_nodes/np.sum(p_all_nodes)
#             print("Sum prob:",np.sum(p_all_nodes))
#             print("final prob:",p)
            
            #Note: 'p'is a vector having size (1,node_no)   
#             print("probability vector:",p)
            
            #select the next node based on roulette wheel
            next_node=roulette_wheel(p)
            
            #append next node to the tour 
            #made by the ant in the colony
            colony[i].append(next_node)
            
        # to complete the tour, 
        # add the initial node to the end as well
        
        colony[i].append(initial_node)
    return colony

# %%
# let's implement the roulette wheel function
def roulette_wheel(prob_vec):
    """
        Selects the next node based on 
        the cumulative sum of the probabilities 
        in the probability vector
    """
    #cumulative version of the prob_vec (p)
    
    cum_sum_p=np.cumsum(prob_vec)
    
    #choose a random value from 0 to 1
    random_val=np.random.rand()
#     print("random value:",random_val)
    
    #choose the first index as next_node in the probability vector
    #that has value more or equal to the random_val
    
#     print("cum sum:",cum_sum_p)
    
    next_node = np.argwhere(cum_sum_p>=random_val)[0][0]
    
    #return the next_node
    return next_node

# %% [markdown]
# ### Now. let's define a function that calculates the fitness value of the route calculated

# %%
def fitness_function(tour,graph):
    """
        calculates the fitness of the tour
        > basically, it's the sum of cost of all edges
        in the tour.
    """
    fitness=0
    
    for i in range(len(tour)-1):
        
        current_node=tour[i] # current node
        next_node=tour[i+1] # next node
        
        # add the cost of current edge (current_node->next_node)
        # to the overall fitness
        
        fitness = fitness + graph[current_node][next_node]
        
    return fitness

# %% [markdown]
# ### And a function to draw Pheromone graph

# %%
def draw_pheromone(ax,fig,tau,graph):
    """
        Draws pheromone graph
    """
    ax.clear()

    # Maximum value of pheromone
    max_tau=np.max(tau)
    # Minimum value of pheromone
    min_tau=np.min(tau)
    
    # Normalize the tau matrix
    tau_normalized = (tau - min_tau)/(max_tau - min_tau)
    for lat,long,i in zip(top_n_dests['latitude'],top_n_dests['longitude'],range(len(graph))):
        for another_lat,another_long,j in zip(top_n_dests['latitude'],top_n_dests['longitude'],range(len(graph))):

            # create a list holding the two latitude
            lat_list=[lat,another_lat]
            # also create a list holding the two longitudes 
            long_list=[long,another_long]
            ax.plot(lat_list,long_list,color=(0,0,1-tau_normalized[i][j]), marker='o', linestyle='solid',linewidth=10*tau_normalized[i][j]+0.5, markersize=8,mfc = 'white')
            fig.canvas.draw()
            fig.canvas.flush_events()

    
    for title,x,y in zip(top_n_dests['title'],top_n_dests['latitude'],top_n_dests['longitude']):
        label = "{}".format(title)
        ax.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(-5,5), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# %% [markdown]
# ### Also, a function to draw the best tour

# %%
def draw_best_tour(ax,fig,best_tour,graph):
    """
        function to draw the best tour
    """
    ax.clear()

    for i in range(len(best_tour)-1):
        #extract the current node and the next node
        current_node=best_tour[i]
        next_node=best_tour[i+1]
        
        #draw a line between current node and next node
        
        #latitude and longitude of the current node
        lat_current,long_current=top_n_dests.iloc[current_node]['latitude'],top_n_dests.iloc[current_node]['longitude']
        
        #latitude and longitude of the next node
        lat_next,long_next=top_n_dests.iloc[next_node]['latitude'],top_n_dests.iloc[next_node]['longitude']
        
        lat_list=[lat_current,lat_next]
        long_list=[long_current,long_next]
        
        plt.plot(lat_list,long_list,color='green', marker='o', linestyle='solid',linewidth=2, markersize=8,mfc = 'white')
        fig.canvas.draw()
        fig.canvas.flush_events()

        
    #for annotation
    for title,x,y in zip(top_n_dests['title'],top_n_dests['latitude'],top_n_dests['longitude']):
        label = "{}".format(title)
        
        ax.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(-5,5), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center

# %% [markdown]
# ### Also , a function to update the pheromone matrix

# %%
def update_pheromone(tau,colony,fitness_list):
    """
        function to update the pheromone matrix
    """
    node_no=len(colony[1])
    ant_no=len(colony)
    
    for i in range(ant_no):
        # for each ant
        for j in range(node_no-1):
            # for each node in the tour 
            current_node=colony[i][j]
            next_node=colony[i][j+1]
            
            tau[current_node,next_node]=tau[current_node,next_node]+1/fitness_list[i]
            tau[next_node,current_node]=tau[next_node,current_node]+1/fitness_list[i]
    
    return tau

# %%
import time

# %% [markdown]
# ## Main ACO loop

# %%
# Main loop

best_fitness=np.inf
best_tour=[]

# %matplotlib notebook

# fig = plt.figure(figsize=(10,10))
# ax1 = fig.add_subplot(131)
# ax2 = fig.add_subplot(132)
# ax3 = fig.add_subplot(133)

# ax1.title.set_text('Initial Mesh')
# ax2.title.set_text('Pheromone Graph Plot')
# ax3.title.set_text('Best Tour Plot')
# plt.ion()

# # plt.title("Pheromone graph plot:")
# fig.show()
# fig.canvas.draw()

#let's draw the initial graph (mesh) first
# plot_graph(ax1,fig)
time_in=time.time()
for i in range(max_iter):
    # create ant colony
    colony=[] # store it as a list
    colony=create_colony(graph,n,ant_no,tau,eta,alpha,beta,starting_point)
#     print(f"Iteration #{i}:")
#     print(colony)
    
    # initializing fitness_list
    fitness_list=[0]*ant_no
    
    # calculate the fitness value of all ants
    for ant_i in range(ant_no):
        fitness_list[ant_i]=fitness_function(colony[ant_i],graph)
        
#     print(fitness_list)
    
    # find the best ant 
    min_value=np.min(fitness_list)
    min_index=np.argmin(fitness_list) #best ant
    
    if min_value<best_fitness:
        # replace best_fitness even smaller min_value is found
        best_fitness=min_value
        best_tour=colony[min_index] #tour of the best ant
        
#     print("Best fitness: ",best_fitness)
#     print("Best tour: ",best_tour)
    
    # update phermone matrix
    tau=update_pheromone(tau,colony,fitness_list)
    
    # print("Updated pheromone matrix:",tau)
    
    # apply evaporation
    tau=(1-rho)*tau
    
    # print("Updated pheromone matrix:",tau)
    
    # plot the pheromone graph
    # draw_pheromone(ax2,fig,tau,graph)
    
    # plot the best tour
    # draw_best_tour(ax3,fig,best_tour,graph)

#     plt.subplot(1,3,1)
#     %matplotlib tk
#     plt.figure(1)
    
#     draw_pheromone(tau,graph)

    
    
# drawing the best tour plot 
# draw_best_tour(ax3,fig,best_tour,graph)

# drawing end pheromone graph
# draw_pheromone(ax2,fig,tau,graph)

# display the names of destinations in the last tour
# print("Best tour obtained:")
print(best_tour)
time_out=time.time()
print(time_out-time_in)
for i in best_tour:
    print(top_n_dests.iloc[i]["title"],end='')
    print("--->",end='')
# Out:
# [0, 73, 50, 111, 91, 133, 48, 37, 35, 102, 22, 4, 66, 94, 87, 32, 34, 132, 11, 7, 20, 23, 29, 112, 12, 36, 3, 89, 184, 16, 26, 88, 38, 56, 52, 1, 30, 153, 98, 64, 78, 129, 113, 24, 41, 126, 84, 18, 96, 82, 15, 45, 118, 2, 101, 93, 53, 103, 47, 156, 21, 106, 77, 43, 10, 181, 144, 170, 152, 142, 121, 104, 119, 179, 165, 145, 158, 173, 143, 120, 160, 162, 92, 148, 114, 115, 99, 157, 13, 172, 39, 134, 105, 54, 124, 97, 109, 95, 69, 100, 137, 128, 116, 62, 127, 135, 63, 117, 58, 70, 57, 110, 123, 60, 136, 76, 44, 46, 85, 19, 8, 79, 14, 31, 40, 122, 67, 25, 27, 42, 130, 59, 9, 61, 74, 90, 125, 80, 107, 55, 17, 51, 6, 155, 168, 71, 180, 147, 175, 72, 161, 176, 108, 159, 169, 177, 75, 171, 81, 140, 138, 49, 5, 28, 183, 65, 164, 163, 151, 185, 141, 150, 33, 174, 166, 154, 167, 139, 182, 86, 83, 178, 146, 149, 68, 131, 0]
# 14.348279237747192
# Boudhanath Stupa--->Guru Lhakhang Monastery--->Boudha Stupa Thanka Center--->Sara Enterprises--->Jamchen Lhakhang Monastery--->Buddha Park--->Boudha Farmers Market at Utpala Cafe--->Shechen Monastery--->White Monastery--->Khawalung Monastery--->Pullahari Monastery--->Kopan Monastery--->Gokarneshwor Mahadev Temple--->Universal Crafts--->Sundarijal Water Falls--->Vajrayogini Temple--->Templo de Changu Narayan--->Brass and Bronze Museum--->Kailashnath Mahadev--->Namo Buddha (Stupa)--->Phulchoki--->National Botanical Gardens--->Sankhu Village--->Pharping HydroPower Dam--->Dakshinkali Temple--->Taudaha Lake--->Chandragiri Hills--->Bagwati Mandir Temple--->Epic Adventures - Day Tours--->Kumari Chowk--->Kathesimbu Stupa--->Shiva Mandir Temple--->The National Museum--->Tribhuvan Park--->The Natural History Museum--->Swayambhunath Temple--->Amideva Buddha Park--->Himalayan Friends Trekking - Day Tours--->Gauri Gaht--->Military Museum--->Casino Mahjong--->Manjushree Temple--->Ashok Stupa--->Jaganath (Krishna) Temple--->Cathedral of the Assumption of the Blessed Virgin Mary--->Lokta Paper Craft--->Nepal Art Council Gallery--->Babar Mahal Revisted--->Casino Everest--->Aviation Museum--->The Crematoria--->Aarya Ghat--->Pandra Shivalaya--->Pashupatinath Temple--->Kirateshwar Mahadev--->Mrigasthali Deer Park--->Guhyeshwari Temple--->Vishnu Mandir Temple--->Taragaon Museum--->Himalayan Car Rental Nepal--->Budhanilakantha Temple--->Bhadrakali Temple--->Namkha Khyung Dzong Rigdin Choling Monastery--->Nagi Gompa--->Shivapuri Nagarjun National Park--->Nepal Alibaba Treks & Tours Pvt Ltd--->Himalaya Holiday Service--->Friends Adventure Team--->Thai Nepal Travels and Tours--->Adventure-Pulse--->Karmaraja Mahavihara--->Dolma Treks--->Buddha Nepal Art Gallery--->Unique Path Trekking & Expedition--->Vista Trek--->Mountain Delights Treks & Expedition--->Dream Heaven Adventure--->Discovery World Trekking--->Mountain Mart Treks & Expedition--->Handy-Mandy Craft House--->A1 Excursion - Private Day Tours--->Tramping Himalaya--->Big Bell--->Himalayan Quests - Day Tours--->Stone Vishnu Mandir Temple--->Maha Vishnu Mandir Temple--->Monasterio Tibetano Boudhanat--->Nepal Ayurveda Home--->Budhanilkantha--->Osho Divine Zone--->Nagarjun Forest Reserve--->Bisnumati River--->Chyasin Dega Temple--->Manakamana Mandir Temple--->Chandragiri Hill--->Maju Dega Mandir Temple--->Chabdi Barahi Temple--->Mero Chitra Wears--->Kathmandu Fun Park--->Kalikasthan Temple--->Department of Immigration--->Lucky Traders & Exporter--->Rizvi Brothers Paper Mache Gift Shop--->Thahiti Chowk--->Dharmadhaatu Stupa--->Drugon Jangchu Monastery--->Nara Devi Temple--->Itum bahal--->Bishal Bazaar--->Bhimsen Tower--->Shiva Parvati Temple--->Singha Sattal (Silyan Sattal)--->Bhimsen Sthan Temple--->Maru Ganesh Shrine--->Dhansa Dega--->Kashthamandap--->Freak Street (Jhhonchen Tole)--->Basantpur Dabali--->Gaddhi Baithak--->Basantapur Tower--->Kathmandu Durbar Square--->The Tribhuvan, Mahendra, and Birendra Museums--->Hanuman Dhoka--->Kala Bairav--->Degu Taleju Temple--->Shree Tanadevi Temple--->Makhan Tole--->Indra Chowk--->Akash Bhairav Temple--->Seto Machindranath Temple--->Shree Bhawani Shankar Temple--->Annapurna Temple--->Asan--->Ratna Park--->Rani Pokhari (Queen's Pond)--->Ghanta Ghar Clock Tower--->Tri Chandra Collage--->Kashmiri Mosque--->The City Museum Kathmandu--->Durbar Marg Street--->Narayanhiti Palace Museum--->Kaiser Library--->Garden of Dreams--->Third Rock Adventures--->Osho Vision Treks and Expedition--->Tridevi Temple--->Travel Maker South Asia--->The Great Adventure Treks & Expedition - Private Day Tours--->Access Nepal Tour & Trekking--->himalayan arts gallery pltd--->Mosaic Adventure--->Trekking Team Group--->Blue Moon Curio Shop--->Exciting Nepal Treks and Expedition--->Landmark Discovery Treks –  Day Tours--->Destination Himalaya Treks and Expedition--->Woodcraft Gallery--->Outshine Adventure--->Divine Yoga Studio--->Nepal Eco Adventure--->Manhal Healing--->Chhango Adventure C ...

# %%
# plt.savefig('sample.png')

# %%
#actual distance given by Vincenty distance using more accurate ellipsoidal models such as WGS-84 than Haversine
import geopy.distance
total_distance=0 #total actual distance

for i in range(len(best_tour)-1):
    coords_1 = (top_n_dests.iloc[best_tour[i]]["latitude"],top_n_dests.iloc[best_tour[i]]["longitude"])
    coords_2 = (top_n_dests.iloc[best_tour[i+1]]["latitude"],top_n_dests.iloc[best_tour[i+1]]["longitude"])
    
    #names of destinations connected
    src=top_n_dests.iloc[best_tour[i]]["title"]
    dest=top_n_dests.iloc[best_tour[i+1]]["title"]
    distance=geopy.distance.geodesic(coords_1, coords_2).km
    print (f'{str(src)+"->"+str(dest)}',distance)
    total_distance=total_distance+distance

print("Total distance(km): ",total_distance)
# Out:
# Boudhanath Stupa->Guru Lhakhang Monastery 0.0579728509975531
# Guru Lhakhang Monastery->Boudha Stupa Thanka Center 0.10895537810120313
# Boudha Stupa Thanka Center->Sara Enterprises 0.07504265981289523
# Sara Enterprises->Jamchen Lhakhang Monastery 0.0674976965974918
# Jamchen Lhakhang Monastery->Buddha Park 0.09779098307752371
# Buddha Park->Boudha Farmers Market at Utpala Cafe 0.24780177611013213
# Boudha Farmers Market at Utpala Cafe->Shechen Monastery 0.17521402809011333
# Shechen Monastery->White Monastery 0.8939207857647852
# White Monastery->Khawalung Monastery 1.1374089864885273
# Khawalung Monastery->Pullahari Monastery 0.3471494011151022
# Pullahari Monastery->Kopan Monastery 0.8250061123659818
# Kopan Monastery->Gokarneshwor Mahadev Temple 2.3270370631625847
# Gokarneshwor Mahadev Temple->Universal Crafts 2.4679375240075916
# Universal Crafts->Sundarijal Water Falls 5.937172168497511
# Sundarijal Water Falls->Vajrayogini Temple 4.815274716869781
# Vajrayogini Temple->Templo de Changu Narayan 4.913554333635855
# Templo de Changu Narayan->Brass and Bronze Museum 4.578020630902609
# Brass and Bronze Museum->Kailashnath Mahadev 4.882662848343698
# Kailashnath Mahadev->Namo Buddha (Stupa) 13.417091282781502
# Namo Buddha (Stupa)->Phulchoki 18.743477022959734
# Phulchoki->National Botanical Gardens 3.0307310857485383
# National Botanical Gardens->Sankhu Village 12.240871982297616
# Sankhu Village->Pharping HydroPower Dam 11.324561257299361
# Pharping HydroPower Dam->Dakshinkali Temple 2.675019460475551
# Dakshinkali Temple->Taudaha Lake 4.840897837911384
# Taudaha Lake->Chandragiri Hills 2.483361023975438
# Chandragiri Hills->Bagwati Mandir Temple 3.3305997283039606
# Bagwati Mandir Temple->Epic Adventures - Day Tours 0.4134602131686918
# Epic Adventures - Day Tours->Kumari Chowk 1.501343880401803
# Kumari Chowk->Kathesimbu Stupa 0.840344237628505
# Kathesimbu Stupa->Shiva Mandir Temple 1.1893596603841454
# Shiva Mandir Temple->The National Museum 0.17736445932336295
# The National Museum->Tribhuvan Park 0.22818224083748517
# Tribhuvan Park->The Natural History Museum 0.29877698429391847
# The Natural History Museum->Swayambhunath Temple 0.23933441913125317
# Swayambhunath Temple->Amideva Buddha Park 0.4821824186589587
# Amideva Buddha Park->Himalayan Friends Trekking - Day Tours 0.702844913076537
# Himalayan Friends Trekking - Day Tours->Gauri Gaht 0.5375004450974428
# Gauri Gaht->Military Museum 0.6593724003915945
# Military Museum->Casino Mahjong 0.9693910679325797
# Casino Mahjong->Manjushree Temple 0.5665002201949624
# Manjushree Temple->Ashok Stupa 0.7609334679834548
# Ashok Stupa->Jaganath (Krishna) Temple 0.9541408706745772
# Jaganath (Krishna) Temple->Cathedral of the Assumption of the Blessed Virgin Mary 1.8627086631676937
# Cathedral of the Assumption of the Blessed Virgin Mary->Lokta Paper Craft 0.4052971773509359
# Lokta Paper Craft->Nepal Art Council Gallery 2.846041120009332
# Nepal Art Council Gallery->Babar Mahal Revisted 0.24376418914089013
# Babar Mahal Revisted->Casino Everest 1.1400432139588066
# Casino Everest->Aviation Museum 2.0475637835165923
# Aviation Museum->The Crematoria 1.4788977118405742
# The Crematoria->Aarya Ghat 0.3413347297505183
# Aarya Ghat->Pandra Shivalaya 0.11362873206567503
# Pandra Shivalaya->Pashupatinath Temple 0.06715736274817251
# Pashupatinath Temple->Kirateshwar Mahadev 0.2634557163149654
# Kirateshwar Mahadev->Mrigasthali Deer Park 0.22314156822176678
# Mrigasthali Deer Park->Guhyeshwari Temple 0.14769902057355513
# Guhyeshwari Temple->Vishnu Mandir Temple 1.215322542910338
# Vishnu Mandir Temple->Taragaon Museum 0.6615840136783118
# Taragaon Museum->Himalayan Car Rental Nepal 5.235492594293197
# Himalayan Car Rental Nepal->Budhanilakantha Temple 0.7913274094719829
# Budhanilakantha Temple->Bhadrakali Temple 2.3230448776378774
# Bhadrakali Temple->Namkha Khyung Dzong Rigdin Choling Monastery 2.4204017443730916
# Namkha Khyung Dzong Rigdin Choling Monastery->Nagi Gompa 3.136359274885935
# Nagi Gompa->Shivapuri Nagarjun National Park 3.4262219665575535
# Shivapuri Nagarjun National Park->Nepal Alibaba Treks & Tours Pvt Ltd 10.413768179647574
# Nepal Alibaba Treks & Tours Pvt Ltd->Himalaya Holiday Service 1.2527037964399024
# Himalaya Holiday Service->Friends Adventure Team 0.28517924203466005
# Friends Adventure Team->Thai Nepal Travels and Tours 0.2682623607749593
# Thai Nepal Travels and Tours->Adventure-Pulse 0.519823642879831
# Adventure-Pulse->Karmaraja Mahavihara 0.06457881228430101
# Karmaraja Mahavihara->Dolma Treks 0.32694425577363
# Dolma Treks->Buddha Nepal Art Gallery 0.11691164394409816
# Buddha Nepal Art Gallery->Unique Path Trekking & Expedition 0.04266276918650674
# Unique Path Trekking & Expedition->Vista Trek 0.016770947715965646
# Vista Trek->Mountain Delights Treks & Expedition 0.062153572068771874
# Mountain Delights Treks & Expedition->Dream Heaven Adventure 0.13233543930032
# Dream Heaven Adventure->Discovery World Trekking 0.04815558978626703
# Discovery World Trekking->Mountain Mart Treks & Expedition 0.13575145776680486
# Mountain Mart Treks & Expedition->Handy-Mandy Craft House 0.29684656785494645
# Handy-Mandy Craft House->A1 Excursion - Private Day Tours 0.15000531333377812
# A1 Excursion - Private Day Tours->Tramping Himalaya 0.22583782831014773
# Tramping Himalaya->Big Bell 0.6877014808776922
# Big Bell->Himalayan Quests - Day Tours 0.7168738125718616
# Himalayan Quests - Day Tours->Stone Vishnu Mandir Temple 1.6921247702270792
# Stone Vishnu Mandir Temple->Maha Vishnu Mandir Temple 0.1708520121351972
# Maha Vishnu Mandir Temple->Monasterio Tibetano Boudhanat 1.6252577290503571
# Monasterio Tibetano Boudhanat->Nepal Ayurveda Home 1.411047388809312
# Nepal Ayurveda Home->Budhanilkantha 2.086663410825906
# Budhanilkantha->Osho Divine Zone 2.126929912746415
# Osho Divine Zone->Nagarjun Forest Reserve 2.717765957034102
# Nagarjun Forest Reserve->Bisnumati River 1.9482308622816156
# Bisnumati River->Chyasin Dega Temple 1.0913410976787372
# Chyasin Dega Temple->Manakamana Mandir Temple 2.036840530523162
# Manakamana Mandir Temple->Chandragiri Hill 5.241391617274237
# Chandragiri Hill->Maju Dega Mandir Temple 4.058873758866002
# Maju Dega Mandir Temple->Chabdi Barahi Temple 159.9068694403196
# Chabdi Barahi Temple->Mero Chitra Wears 54.27983980551058
# Mero Chitra Wears->Kathmandu Fun Park 143.3179252790813
# Kathmandu Fun Park->Kalikasthan Temple 0.6274022266299859
# Kalikasthan Temple->Department of Immigration 0.24593896332866724
# Department of Immigration->Lucky Traders & Exporter 1.769525451573034
# Lucky Traders & Exporter->Rizvi Brothers Paper Mache Gift Shop 0.11899930011580945
# Rizvi Brothers Paper Mache Gift Shop->Thahiti Chowk 0.27143191290222807
# Thahiti Chowk->Dharmadhaatu Stupa 0.02862154594465558
# Dharmadhaatu Stupa->Drugon Jangchu Monastery 0.09743300308870594
# Drugon Jangchu Monastery->Nara Devi Temple 0.361245025762809
# Nara Devi Temple->Itum bahal 0.11839713035546408
# Itum bahal->Bishal Bazaar 0.33892944954237547
# Bishal Bazaar->Bhimsen Tower 0.45968227135404793
# Bhimsen Tower->Shiva Parvati Temple 0.4614025170976507
# Shiva Parvati Temple->Singha Sattal (Silyan Sattal) 0.22394678556442751
# Singha Sattal (Silyan Sattal)->Bhimsen Sthan Temple 0.3564595355195845
# Bhimsen Sthan Temple->Maru Ganesh Shrine 0.2460147794261592
# Maru Ganesh Shrine->Dhansa Dega 0.04054976513195206
# Dhansa Dega->Kashthamandap 0.01592903033362686
# Kashthamandap->Freak Street (Jhhonchen Tole) 0.099200580081985
# Freak Street (Jhhonchen Tole)->Basantpur Dabali 0.06263657301574545
# Basantpur Dabali->Gaddhi Baithak 0.08144549384956044
# Gaddhi Baithak->Basantapur Tower 0.022097118517819953
# Basantapur Tower->Kathmandu Durbar Square 0.004733868416970866
# Kathmandu Durbar Square->The Tribhuvan, Mahendra, and Birendra Museums 0.06614365864319174
# The Tribhuvan, Mahendra, and Birendra Museums->Hanuman Dhoka 0.011476239808987404
# Hanuman Dhoka->Kala Bairav 0.06957466892048184
# Kala Bairav->Degu Taleju Temple 0.09261570206319261
# Degu Taleju Temple->Shree Tanadevi Temple 0.04082443552554983
# Shree Tanadevi Temple->Makhan Tole 0.07052434770533582
# Makhan Tole->Indra Chowk 0.062140690019875405
# Indra Chowk->Akash Bhairav Temple 0.03667829724107677
# Akash Bhairav Temple->Seto Machindranath Temple 0.1083238181314879
# Seto Machindranath Temple->Shree Bhawani Shankar Temple 0.035516578861442244
# Shree Bhawani Shankar Temple->Annapurna Temple 0.22581023645141057
# Annapurna Temple->Asan 0.029726635357566627
# Asan->Ratna Park 0.23082931332678575
# Ratna Park->Rani Pokhari (Queen's Pond) 0.15658600750024554
# Rani Pokhari (Queen's Pond)->Ghanta Ghar Clock Tower 0.158123491465984
# Ghanta Ghar Clock Tower->Tri Chandra Collage 0.14204238709296194
# Tri Chandra Collage->Kashmiri Mosque 0.1116859911433763
# Kashmiri Mosque->The City Museum Kathmandu 0.27564383821915744
# The City Museum Kathmandu->Durbar Marg Street 0.154054924936911
# Durbar Marg Street->Narayanhiti Palace Museum 0.28389878881963204
# Narayanhiti Palace Museum->Kaiser Library 0.3102784126016735
# Kaiser Library->Garden of Dreams 0.0873039559134398
# Garden of Dreams->Third Rock Adventures 0.07023811170668202
# Third Rock Adventures->Osho Vision Treks and Expedition 0.06775284477853757
# Osho Vision Treks and Expedition->Tridevi Temple 0.05868970582254677
# Tridevi Temple->Travel Maker South Asia 0.06677862877355349
# Travel Maker South Asia->The Great Adventure Treks & Expedition - Private Day Tours 0.11873958783941915
# The Great Adventure Treks & Expedition - Private Day Tours->Access Nepal Tour & Trekking 0.039857124495355
# Access Nepal Tour & Trekking->himalayan arts gallery pltd 0.09169364366054918
# himalayan arts gallery pltd->Mosaic Adventure 0.04847462719462089
# Mosaic Adventure->Trekking Team Group 0.07653931791819678
# Trekking Team Group->Blue Moon Curio Shop 0.04983776027667931
# Blue Moon Curio Shop->Exciting Nepal Treks and Expedition 0.1244691771615435
# Exciting Nepal Treks and Expedition->Landmark Discovery Treks –  Day Tours 0.11551347602326215
# Landmark Discovery Treks –  Day Tours->Destination Himalaya Treks and Expedition 0.038310754523808006
# Destination Himalaya Treks and Expedition->Woodcraft Gallery 0.021758730222479598
# Woodcraft Gallery->Outshine Adventure 0.014284736746915017
# Outshine Adventure->Divine Yoga Studio 0.003981637484986713
# Divine Yoga Studio->Nepal Eco Adventure 0.052904196897497306
# Nepal Eco Adventure->Manhal Healing 0.08115026089075596
# Manhal Healing->Chhango Adventure Canyoning In Nepal 0.06819987135860696
# Chhango Adventure Canyoning In Nepal->Thamel 0.03451922901090374
# Thamel->Mandala Street 0.0742303929698979
# Mandala Street->Info Nepal Treks and Expedition 0.10132792264014942
# Info Nepal Treks and Expedition->Shanti Spa 0.014086748088015981
# Shanti Spa->Pariwar Holidays 0.08587875148081625
# Pariwar Holidays->Destination Unlimited Treks & Expeditions 0.044120911936022626
# Destination Unlimited Treks & Expeditions->Visit Himalaya Treks 0.020046278587886542
# Visit Himalaya Treks->Hiking Adventure Treks 0.05228674402932186
# Hiking Adventure Treks->Ace the Himalaya 0.1266496408068372
# Ace the Himalaya->Magical Nepal 0.06393023820014863
# Magical Nepal->Astrek Climbing Wall 0.08453734366454348
# Astrek Climbing Wall->Nepal Gateway Trekking 0.034300079309568916
# Nepal Gateway Trekking->Odea Services 0.026810336832294567
# Odea Services->Mountain Holiday Treks & Expedition 0.08909592926548429
# Mountain Holiday Treks & Expedition->Ambition Himalaya Treks & Expeditions 0.02305105111080969
# Ambition Himalaya Treks & Expeditions->Nepal Hiking Team 0.6506313586013437
# Nepal Hiking Team->Alpine Ramble Treks 0.09180194969930279
# Alpine Ramble Treks->Casino Rad 1.2838491523452853
# Casino Rad->Millionaire's Club and Casino 0.6091448812747116
# Millionaire's Club and Casino->Earthbound Expeditions 2.0081188271626704
# Earthbound Expeditions->Nepal Horizon Treks & Expedition 0.014795325796175474
# Nepal Horizon Treks & Expedition->Incredible Treks 0.09706056235151453
# Incredible Treks->Music Museum of Nepal 2.1070022662881085
# Music Museum of Nepal->Direction Exhibition & Convention Center 0.15201214758264234
# Direction Exhibition & Convention Center->Boudhanath Stupa 5.642079853236588
# Total distance(km):  569.9811370856065
